# %%
# If needed, uncomment these:
# %pip install pandas geopandas pyproj shapely scikit-learn tqdm

import os
import re
import glob
import math
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
from sklearn.neighbors import BallTree
from tqdm import tqdm
tqdm.pandas()

# %%
# Project-relative paths (adjust if different)
DATA_DIR = "data"
OUT_DIR  = "out"
os.makedirs(OUT_DIR, exist_ok=True)

# Your files
ZCTA_DIR = os.path.join(DATA_DIR, "tl_2020_us_zcta510")
RUCA_CSV = os.path.join(DATA_DIR, "RUCA-codes-2020-zipcode.csv")

# Trial files (all *_with_zip.csv)
TRIAL_FILES = sorted(glob.glob(os.path.join(DATA_DIR, "*_with_zip.csv")))

# If you later download ACS/NHGIS population by ZCTA, set the path here:
ACS_POP_FILE = None  # e.g., "../data/nhgis/acs_zcta_population.csv"

# Column names that might contain a ZIP (we'll search in this list)
ZIP_COLS = ["zip", "zipcode", "ZIP", "ZIPCode"]

# --- helpers ---
ZIP_RE = re.compile(r"^\d{5}$")

def to_zip5(x):
    """Return 5-digit ZIP string or None."""
    if pd.isna(x):
        return None
    s = str(x).strip()
    # strip 4+4 formats or text
    s = re.sub(r"[^\d]", "", s)
    if len(s) >= 5:
        s = s[:5]
    return s if ZIP_RE.match(s) else None

def classify_rural_urban(primary_ruca):
    """
    RUCA: typical cut:
      Urban: 1.0–3.0
      Rural: 4.0–10.0
    Returns 'Urban' or 'Rural' (None if missing)
    """
    try:
        p = float(primary_ruca)
    except:
        return None
    return "Urban" if 1 <= p < 4 else "Rural"

# %%
# Load 2020 ZCTA polygons
zcta = gpd.read_file(ZCTA_DIR)

# Typical id column names in tl_2020_us_zcta510:
# 'ZCTA5CE10' (5-digit ZCTA code), geometry
id_col = "ZCTA5CE10" if "ZCTA5CE10" in zcta.columns else None
assert id_col is not None, f"Could not find ZCTA id col in {list(zcta.columns)}"

# Ensure CRS is WGS84 and compute centroids
if zcta.crs is None or zcta.crs.to_epsg() != 4269:
    # These TIGER files are usually EPSG:4269 (NAD83); we’ll project to 4326 for lat/lon
    pass

zcta = zcta.to_crs(epsg=4326)
zcta["centroid"] = zcta.geometry.centroid
zcta["lon"] = zcta["centroid"].x
zcta["lat"] = zcta["centroid"].y

zip_centroids = zcta[[id_col, "lat", "lon"]].rename(columns={id_col: "zip"})
# make sure zip is 5-digit string
zip_centroids["zip"] = zip_centroids["zip"].astype(str).str.zfill(5)

print(zip_centroids.head())
print(f"ZCTA count: {len(zip_centroids):,}")
# Out:
# /var/folders/4l/64tth9h948n3dbq1py15y2qr0000gn/T/ipykernel_76260/2670556587.py:15: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zcta["centroid"] = zcta.geometry.centroid
#      zip        lat        lon
# 0  43451  41.312827 -83.615185
# 1  43452  41.515177 -82.966801
# 2  43456  41.668369 -82.822768
# 3  43457  41.267330 -83.427484
# 4  43458  41.531051 -83.212587
# ZCTA count: 33,144

# %%
ruca = pd.read_csv(RUCA_CSV, dtype=str)
# Your sample columns looked like: ZIPCode, State, ZIPCodeType, POName, PrimaryRUCA, SecondaryRUCA
# Standardize
ruca["zip"] = ruca["ZIPCode"].apply(to_zip5)
ruca["PrimaryRUCA_num"] = pd.to_numeric(ruca["PrimaryRUCA"], errors="coerce")
ruca["rural_urban"] = ruca["PrimaryRUCA_num"].apply(classify_rural_urban)

ruca = ruca[["zip", "PrimaryRUCA", "rural_urban"]].dropna(subset=["zip"]).drop_duplicates()
print(ruca["rural_urban"].value_counts(dropna=False))
# Out:
# rural_urban
# Urban    23381
# Rural    17765
# Name: count, dtype: int64

# %%
# 4) Load & combine all GI trial site CSVs

ZIP_COLS = ["zip", "zipcode", "Zipcode", "ZIP", "ZIPCode", "Zip", "postal_code"]

ZIP_RE = re.compile(r"\b\d{5}\b")

def extract_zips_from_locations(text):
    if pd.isna(text):
        return []
    s = str(text)
    # Find all 5-digit substrings (handles things like "... MA 02115; Houston, TX 77030")
    zips = ZIP_RE.findall(s)
    # Deduplicate while preserving order
    seen = set()
    out = []
    for z in zips:
        if z not in seen:
            seen.add(z)
            out.append(z)
    return out

def load_trials_one(path):
    df = pd.read_csv(path, dtype=str)
    
    # Try to find an explicit ZIP column first
    zip_col = None
    for c in ZIP_COLS:
        if c in df.columns:
            zip_col = c
            break

    if zip_col is not None:
        df["zip"] = df[zip_col].apply(to_zip5)
        df = df.dropna(subset=["zip"]).copy()
    elif "Locations" in df.columns:
        # Fallback: parse from Locations text (explode to one row per ZIP)
        df["__zips_list"] = df["Locations"].apply(extract_zips_from_locations)
        df = df.explode("__zips_list")
        df["zip"] = df["__zips_list"].apply(to_zip5)
        df = df.dropna(subset=["zip"]).drop(columns="__zips_list")
    else:
        raise ValueError(
            f"No ZIP column and no 'Locations' field to parse in {path}. "
            f"Available columns: {list(df.columns)}"
        )

    # Infer cancer type from filename if not present
    if "cancer_type" not in df.columns:
        fname = os.path.basename(path).lower()
        cancer = re.sub(r"_with_zip.*$", "", fname).replace(".csv", "")
        df["cancer_type"] = cancer

    # Keep only what we need
    keep_cols = ["NCT Number","Study Title","Conditions","Interventions","Sponsor","Locations"]
    for col in keep_cols:
        if col not in df.columns:
            df[col] = np.nan

    return df[keep_cols + ["zip","cancer_type"]]

trial_list = []
for f in TRIAL_FILES:
    try:
        trial_list.append(load_trials_one(f))
        print(f"Loaded: {os.path.basename(f)} ({len(trial_list[-1]):,} rows after ZIP parsing)")
    except Exception as e:
        print(f"Skipping {f}: {e}")

trials = (
    pd.concat(trial_list, ignore_index=True)
    if trial_list else
    pd.DataFrame(columns=["zip","cancer_type"])
)

# Dedup by trial site ZIP within each cancer type
trials = trials.drop_duplicates(subset=["zip","cancer_type"]).reset_index(drop=True)

print(trials.head())
print(f"Unique trial ZIP entries: {len(trials):,} across {trials['cancer_type'].nunique()} cancer types")
# Out:
# Loaded: Oesophageal_cancer_with_zip.csv (3,090 rows after ZIP parsing)
# Loaded: cholangiocarcinoma_with_zip.csv (774 rows after ZIP parsing)
# Loaded: colorectal_cancer_with_zip.csv (6,396 rows after ZIP parsing)
# Loaded: gastric_cancer_with_zip.csv (5,287 rows after ZIP parsing)
# Loaded: hepatocellular_cancer_with_zip.csv (1,123 rows after ZIP parsing)
# Loaded: pancreatic_cancer_with_zip.csv (5,441 rows after ZIP parsing)
#     NCT Number                                        Study Title  \
# 0  NCT01684904               Proton Therapy for Esophageal Cancer
# 1  NCT06872515  Impact of Prehabilitation in Oncology Via Exer...
# 2  NCT06906887  PULSO Trial: Pulsed Low-Dose-Rate (PLDR) Radia...
# 3  NCT06430346  Exercise Prehabilitation for Locoregional Esop...
# 4  NCT06414902  18F-AraG PET/CT as a Non-Invasive Imaging Biom...
#
#                                           Conditions  \
# 0                                   Esophagus Cancer
# 1             Esophageal Cancer|Esophageal Carcinoma
# 2  Esophageal Cancer|Oesophageal Cancer|GastroEso...
# 3                                  Esophageal Cancer
# 4                                  Esophageal Cancer
#
#                                        Interventions  \
# 0                        RADIATION: Proton radiation
# 1  BEHAVIORAL: Exercise and Nutrition|BEHAVIORAL:...
# 2  DRUG: Induction Chemotherapy (modified FLOT or...
# 3                               BEHAVIORAL: Exercise
# 4          DRUG: ArabinoFuranosylGuanine [18F]F-AraG
#
#                                              Sponsor  \
# 0                              Loma Linda University
# 1                           University of Pittsburgh
# 2                       Medical College of Wisconsin
# 3  H. Lee Moffitt Cancer Center and Research Inst...
# 4                        M.D. Anderson Cancer Center
#
#                                            Locations    zip  \
# 0  Loma Linda University Medical Center, Loma Lin...  92354
# 1  UPMC Hillman Cancer Center, Pittsburgh, Pennsy...  15213
# 2  Froedtert & the Medical College of Wisconsin, ...  53226
# 3  Moffitt Cancer Center, Tampa, Florida, 33612, ...  33612
# 4  MD Anderson Cancer Center, Houston, Texas, 770...  77030
#
#           cancer_type
# 0  oesophageal_cancer
# 1  oesophageal_cancer
# 2  oesophageal_cancer
# 3  oesophageal_cancer
# 4  oesophageal_cancer
# Unique trial ZIP entries: 7,241 across 6 cancer types

# %%
trial_sites = trials.merge(zip_centroids, on="zip", how="left")
missing_geo = trial_sites["lat"].isna().sum()
if missing_geo:
    print(f"WARNING: {missing_geo} trial rows lack ZCTA centroid match. They will be dropped for distance calcs.")
trial_sites = trial_sites.dropna(subset=["lat","lon"]).copy()

# Build one per ZIP per cancer type (we already deduped), keep site coordinates
trial_sites = trial_sites[["zip","cancer_type","lat","lon"]].drop_duplicates()
print(trial_sites.head())
print(f"Geocoded trial site rows: {len(trial_sites):,}")
# Out:
# WARNING: 1329 trial rows lack ZCTA centroid match. They will be dropped for distance calcs.
#      zip         cancer_type        lat         lon
# 0  92354  oesophageal_cancer  34.049773 -117.251508
# 1  15213  oesophageal_cancer  40.444041  -79.955247
# 2  53226  oesophageal_cancer  43.049438  -88.042176
# 3  33612  oesophageal_cancer  28.050741  -82.449746
# 4  77030  oesophageal_cancer  29.706274  -95.402594
# Geocoded trial site rows: 5,912

# %%
zip_universe = zip_centroids.merge(ruca, on="zip", how="left")

# Optional: attach population if you have ACS later
if ACS_POP_FILE and os.path.exists(ACS_POP_FILE):
    pop = pd.read_csv(ACS_POP_FILE, dtype={ "zip": str })
    pop["zip"] = pop["zip"].apply(to_zip5)
    pop = pop.dropna(subset=["zip"])
    # Expect a 'population' column in ACS file
    if "population" in pop.columns:
        zip_universe = zip_universe.merge(pop[["zip","population"]], on="zip", how="left")
    else:
        print("ACS file found but no 'population' column detected; skipping population merge.")
else:
    zip_universe["population"] = np.nan  # placeholder

# Keep only ZIPs with coordinates and RUCA classification for coverage stats
zip_universe = zip_universe.dropna(subset=["lat","lon"])
print(zip_universe.head())
print(f"Zip universe rows: {len(zip_universe):,}")
# Out:
#      zip        lat        lon PrimaryRUCA rural_urban  population
# 0  43451  41.312827 -83.615185           2       Urban         NaN
# 1  43452  41.515177 -82.966801           1       Urban         NaN
# 2  43456  41.668369 -82.822768          10       Rural         NaN
# 3  43457  41.267330 -83.427484           3       Urban         NaN
# 4  43458  41.531051 -83.212587           2       Urban         NaN
# Zip universe rows: 33,144

# %%
# Build a BallTree (haversine) for each cancer type and for "any GI trial"
EARTH_RADIUS_MILES = 3958.7613
RADIUS_MILES = 50.0
radius_radians = RADIUS_MILES / EARTH_RADIUS_MILES

def build_tree(df):
    # expects columns: lat, lon in degrees
    pts = np.deg2rad(df[["lat","lon"]].values)
    return BallTree(pts, metric="haversine"), pts

# "Any GI" tree
any_tree, any_pts = build_tree(trial_sites)

# Cancer-specific trees
trees_by_cancer = {}
for cancer, dfc in trial_sites.groupby("cancer_type"):
    trees_by_cancer[cancer] = build_tree(dfc)

# Now query coverage for each ZIP centroid
query_pts = np.deg2rad(zip_universe[["lat","lon"]].values)

# Any GI within 50 miles?
ind_any = any_tree.query_radius(query_pts, r=radius_radians)
zip_universe["covered_any_gi_50mi"] = [1 if len(ix)>0 else 0 for ix in ind_any]

# Cancer-specific coverage flags
for cancer, (tree, _) in trees_by_cancer.items():
    inds = tree.query_radius(query_pts, r=radius_radians)
    flag = [1 if len(ix)>0 else 0 for ix in inds]
    col = f"covered_{cancer}_50mi"
    # sanitize col name (just in case)
    col = re.sub(r"[^a-z0-9_]+","_", col.lower())
    zip_universe[col] = flag

zip_universe.head()
# Out:
#      zip        lat        lon PrimaryRUCA rural_urban  population  \
# 0  43451  41.312827 -83.615185           2       Urban         NaN
# 1  43452  41.515177 -82.966801           1       Urban         NaN
# 2  43456  41.668369 -82.822768          10       Rural         NaN
# 3  43457  41.267330 -83.427484           3       Urban         NaN
# 4  43458  41.531051 -83.212587           2       Urban         NaN
#
#    covered_any_gi_50mi  covered_cholangiocarcinoma_50mi  \
# 0                    1                                0
# 1                    1                                0
# 2                    1                                1
# 3                    1                                0
# 4                    1                                0
#
#    covered_colorectal_cancer_50mi  covered_gastric_cancer_50mi  \
# 0                               1                            1
# 1                               1                            1
# 2                               1                            1
# 3                               1                            1
# 4                               1                            1
#
#    covered_hepatocellular_cancer_50mi  covered_oesophageal_cancer_50mi  \
# 0                                   1                                1
# 1                                   1                                1
# 2                                   1                                1
# 3                                   1                                1
# 4                                   1                                1
#
#    covered_pancreatic_cancer_50mi
# 0                               1
# 1                               1
# 2                               1
# 3                               1
# 4                               1

# %%
def summarize_coverage(df, cover_col, weight_col=None):
    # Drop rows with unknown RUCA classification
    dfx = df[df["rural_urban"].isin(["Urban","Rural"])].copy()
    if not len(dfx):
        return pd.DataFrame()

    if weight_col and weight_col in dfx.columns and dfx[weight_col].notna().any():
        # Weighted share = sum(w * covered) / sum(w)
        grp = dfx.groupby("rural_urban").apply(
            lambda g: pd.Series({
                "n_zips": len(g),
                "share_covered_unweighted": g[cover_col].mean(),
                "pop_covered": (g[cover_col] * g[weight_col]).sum(skipna=True),
                "pop_total": g[weight_col].sum(skipna=True)
            })
        ).reset_index()
        grp["share_covered_weighted"] = grp["pop_covered"] / grp["pop_total"]
        grp.drop(columns=["pop_covered","pop_total"], inplace=True)
    else:
        grp = dfx.groupby("rural_urban").agg(
            n_zips=("zip","count"),
            share_covered_unweighted=(cover_col,"mean")
        ).reset_index()

    grp["coverage_flag"] = cover_col
    return grp

# Any GI coverage summary
summary_any = summarize_coverage(zip_universe, "covered_any_gi_50mi", weight_col="population")

# Per-cancer summaries
cancer_cols = [c for c in zip_universe.columns if c.startswith("covered_") and c.endswith("_50mi") and c != "covered_any_gi_50mi"]
summary_cancers = pd.concat(
    [summarize_coverage(zip_universe, c, weight_col="population") for c in cancer_cols],
    ignore_index=True
) if cancer_cols else pd.DataFrame()

summary_any, summary_cancers.head()
# Out:
# (  rural_urban  n_zips  share_covered_unweighted        coverage_flag
#  0       Rural   16160                  0.773515  covered_any_gi_50mi
#  1       Urban   16960                  0.971226  covered_any_gi_50mi,
#    rural_urban  n_zips  share_covered_unweighted  \
#  0       Rural   16160                  0.337809
#  1       Urban   16960                  0.748054
#  2       Rural   16160                  0.718750
#  3       Urban   16960                  0.957075
#  4       Rural   16160                  0.701238
#
#                       coverage_flag
#  0  covered_cholangiocarcinoma_50mi
#  1  covered_cholangiocarcinoma_50mi
#  2   covered_colorectal_cancer_50mi
#  3   covered_colorectal_cancer_50mi
#  4      covered_gastric_cancer_50mi  )

# %%
zip_universe.head()
# Out:
#      zip        lat        lon PrimaryRUCA rural_urban  population  \
# 0  43451  41.312827 -83.615185           2       Urban         NaN
# 1  43452  41.515177 -82.966801           1       Urban         NaN
# 2  43456  41.668369 -82.822768          10       Rural         NaN
# 3  43457  41.267330 -83.427484           3       Urban         NaN
# 4  43458  41.531051 -83.212587           2       Urban         NaN
#
#    covered_any_gi_50mi  covered_cholangiocarcinoma_50mi  \
# 0                    1                                0
# 1                    1                                0
# 2                    1                                1
# 3                    1                                0
# 4                    1                                0
#
#    covered_colorectal_cancer_50mi  covered_gastric_cancer_50mi  \
# 0                               1                            1
# 1                               1                            1
# 2                               1                            1
# 3                               1                            1
# 4                               1                            1
#
#    covered_hepatocellular_cancer_50mi  covered_oesophageal_cancer_50mi  \
# 0                                   1                                1
# 1                                   1                                1
# 2                                   1                                1
# 3                                   1                                1
# 4                                   1                                1
#
#    covered_pancreatic_cancer_50mi
# 0                               1
# 1                               1
# 2                               1
# 3                               1
# 4                               1

# %%
print("\nAny GI trials within 50 miles:")
print(summary_any)

if not summary_cancers.empty:
    print("\nTop 10 cancer-specific coverage flags:")
    display(summary_cancers.head(10))
# Out:
# Any GI trials within 50 miles:
#   rural_urban  n_zips  share_covered_unweighted        coverage_flag
# 0       Rural   16160                  0.773515  covered_any_gi_50mi
# 1       Urban   16960                  0.971226  covered_any_gi_50mi
#
# Top 10 cancer-specific coverage flags:
#   rural_urban  n_zips  share_covered_unweighted  \
# 0       Rural   16160                  0.337809
# 1       Urban   16960                  0.748054
# 2       Rural   16160                  0.718750
# 3       Urban   16960                  0.957075
# 4       Rural   16160                  0.701238
# 5       Urban   16960                  0.943101
# 6       Rural   16160                  0.330631
# 7       Urban   16960                  0.768337
# 8       Rural   16160                  0.624443
# 9       Urban   16960                  0.897465
#
#                         coverage_flag
# 0     covered_cholangiocarcinoma_50mi
# 1     covered_cholangiocarcinoma_50mi
# 2      covered_colorectal_cancer_50mi
# 3      covered_colorectal_cancer_50mi
# 4         covered_gastric_cancer_50mi
# 5         covered_gastric_cancer_50mi
# 6  covered_hepatocellular_cancer_50mi
# 7  covered_hepatocellular_cancer_50mi
# 8     covered_oesophageal_cancer_50mi
# 9     covered_oesophageal_cancer_50mi

# %%
# QC: counts & missing RUCA
print("ZIP universe rows:", len(zip_universe))
print(zip_universe["rural_urban"].value_counts(dropna=False))

missing_ruca = zip_universe["rural_urban"].isna().sum()
if missing_ruca:
    print(f"WARNING: {missing_ruca} ZIPs have missing RUCA; excluded from summaries.")
# Out:
# ZIP universe rows: 33144
# rural_urban
# Urban    16960
# Rural    16160
# NaN         24
# Name: count, dtype: int64
# WARNING: 24 ZIPs have missing RUCA; excluded from summaries.

# %%
import math
import pandas as pd
from statsmodels.stats.proportion import proportions_ztest, proportion_confint

def two_group_stats(df, cover_col):
    dfx = df[df["rural_urban"].isin(["Urban","Rural"])].copy()
    # counts by group
    def grp_counts(g):
        n = len(g)
        x = g[cover_col].sum()
        p = x / n if n else float("nan")
        # Wilson CI for single proportion
        low, high = proportion_confint(count=x, nobs=n, method="wilson")
        return pd.Series({"n": n, "x": x, "p": p, "p_low": low, "p_high": high})

    tab = dfx.groupby("rural_urban").apply(grp_counts).reset_index()
    # pivot to have Rural/Urban on one row
    row = {"coverage_flag": cover_col}
    for _, r in tab.iterrows():
        g = r["rural_urban"].lower()
        row[f"n_{g}"] = int(r["n"])
        row[f"x_{g}"] = int(r["x"])
        row[f"p_{g}"] = r["p"]
        row[f"p_{g}_low"] = r["p_low"]
        row[f"p_{g}_high"] = r["p_high"]

    # difference & ratio
    p_rur, p_urb = row["p_rural"], row["p_urban"]
    row["risk_difference"] = p_urb - p_rur
    row["risk_ratio"] = (p_urb / p_rur) if (p_rur and not math.isnan(p_rur)) else float("nan")

    # two-proportion z-test (H0: p_rural == p_urban)
    count = np.array([row["x_rural"], row["x_urban"]])
    nobs  = np.array([row["n_rural"], row["n_urban"]])
    z, pval = proportions_ztest(count, nobs, alternative="two-sided")
    row["z_stat"] = z
    row["p_value"] = pval
    return pd.Series(row)

# Build list of coverage columns
coverage_cols = ["covered_any_gi_50mi"] + [
    c for c in zip_universe.columns
    if c.startswith("covered_") and c.endswith("_50mi") and c != "covered_any_gi_50mi"
]

effect_rows = [two_group_stats(zip_universe, col) for col in coverage_cols]
effects_df = pd.DataFrame(effect_rows).sort_values("risk_difference", ascending=False)

# Pretty print & save
pd.set_option("display.max_columns", None)
display(effects_df)
effects_df.to_csv("out/effects_50mi_by_cancer.csv", index=False)
print("Saved out/effects_50mi_by_cancer.csv")
# Out:
# /var/folders/4l/64tth9h948n3dbq1py15y2qr0000gn/T/ipykernel_76260/2799353841.py:16: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tab = dfx.groupby("rural_urban").apply(grp_counts).reset_index()
# /var/folders/4l/64tth9h948n3dbq1py15y2qr0000gn/T/ipykernel_76260/2799353841.py:16: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tab = dfx.groupby("rural_urban").apply(grp_counts).reset_index()
# /var/folders/4l/64tth9h948n3dbq1py15y2qr0000gn/T/ipykernel_76260/2799353841.py:16: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tab = dfx.groupby("rural_urban").apply(grp_counts).reset_index()
# /var/folders/4l/64tth9h948n3dbq1py15y2qr0000gn/T/ipykernel_76260/2799353841.py:16: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tab = dfx.groupby("rural_urban").apply(grp_counts).reset_index()
# /var/folders/4l/64tth9h948n3dbq1py15y2qr0000gn/T/ipykernel_76260/2799353841.py:16: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tab = dfx.groupby("rural_urban").apply(grp_counts).reset_index()
# /var/folders/4l/64tth9h948n3dbq1py15y2qr0000gn/T/ipykernel_76260/2799353841.py:16: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tab = dfx.groupby("rural_urban").apply(grp_counts).reset_index()
# /var/folders/4l/64tth9h948n3dbq1py15y2qr0000gn/T/ipykernel_76260/2799353841.py:16: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tab = dfx.groupby("rural_urban").apply(grp_counts).reset_index()
#                         coverage_flag  n_rural  x_rural   p_rural  \
# 4  covered_hepatocellular_cancer_50mi    16160     5343  0.330631
# 1     covered_cholangiocarcinoma_50mi    16160     5459  0.337809
# 5     covered_oesophageal_cancer_50mi    16160    10091  0.624443
# 6      covered_pancreatic_cancer_50mi    16160    10931  0.676423
# 3         covered_gastric_cancer_50mi    16160    11332  0.701238
# 2      covered_colorectal_cancer_50mi    16160    11615  0.718750
# 0                 covered_any_gi_50mi    16160    12500  0.773515
#
#    p_rural_low  p_rural_high  n_urban  x_urban   p_urban  p_urban_low  \
# 4     0.323419      0.337924    16960    13031  0.768337     0.761927
# 1     0.330557      0.345139    16960    12687  0.748054     0.741465
# 5     0.616948      0.631879    16960    15221  0.897465     0.892809
# 6     0.669169      0.683594    16960    15917  0.938502     0.934786
# 3     0.694133      0.708246    16960    15995  0.943101     0.939514
# 2     0.711767      0.725629    16960    16232  0.957075     0.953920
# 0     0.766997      0.779903    16960    16472  0.971226     0.968602
#
#    p_urban_high  risk_difference  risk_ratio     z_stat  p_value
# 4      0.774626         0.437706    2.323850 -80.116574      0.0
# 1      0.754531         0.410245    2.214427 -74.982950      0.0
# 5      0.901940         0.273022    1.437224 -58.511680      0.0
# 6      0.942020         0.262079    1.387448 -60.848818      0.0
# 3      0.946488         0.241864    1.344910 -57.916443      0.0
# 2      0.960024         0.238325    1.331583 -59.255837      0.0
# 0      0.973638         0.197712    1.255602 -54.337822      0.0
# Saved out/effects_50mi_by_cancer.csv

# %%
# 5) Map trial ZIPs to coordinates
print("Step 5: Map trial ZIPs to coordinates")
trial_sites = trials.merge(zip_centroids, on="zip", how="left")
missing_geo = trial_sites["lat"].isna().sum()
print(f"Missing geocodes for trial ZIP rows: {missing_geo}")
trial_sites = trial_sites.dropna(subset=["lat","lon"]).copy()
trial_sites = trial_sites[["zip","cancer_type","lat","lon"]].drop_duplicates()
print(f"Geocoded trial site rows: {len(trial_sites):,}")

# %%
# 6) Build ZIP universe (RUCA + centroids)
print("Step 6: Build ZIP universe (RUCA + centroids)")
zip_universe = zip_centroids.merge(ruca[["zip","PrimaryRUCA","rural_urban"]], on="zip", how="left")
# placeholder population; will be merged next if available
import numpy as np
zip_universe["population"] = np.nan
print(zip_universe.head())
print(f"Zip universe rows: {len(zip_universe):,}")

# %%
# 6b) (Optional) Ingest ACS population CSVs (B01003_001E) and merge
print("Step 6b: Ingest ACS ZCTA population (if CSVs present)")
import os, re, glob
import pandas as pd

ACS_DIR = "../data/acs"  # place your downloaded files here
if not os.path.exists(ACS_DIR):
    os.makedirs(ACS_DIR, exist_ok=True)

def normalize_acs_file(path):
    df = pd.read_csv(path, dtype=str, low_memory=False)
    cols = set(df.columns)

    # detect ZIP/ZCTA column
    zip_col = None
    for c in ["zip code tabulation area","ZCTA","ZCTA5","ZCTA5CE10","ZCTA5A","zip","Zip","NAME","GEO_ID"]:
        if c in cols:
            zip_col = c
            break
    if zip_col == "NAME":
        m = df["NAME"].astype(str).str.extract(r"(\d{5})$")
        df["zip"] = m[0]
        zip_col = "zip"
    elif zip_col == "GEO_ID":
        m = df["GEO_ID"].astype(str).str.extract(r"(\d{5})$")
        df["zip"] = m[0]
        zip_col = "zip"
    if zip_col is None:
        # last resort: search any column with many 5-digit patterns
        for c in df.columns:
            if df[c].astype(str).str.contains(r"\b\d{5}\b").mean() > 0.5:
                df["zip"] = df[c].astype(str).str.extract(r"(\d{5})", expand=False)
                zip_col = "zip"
                break
    if zip_col is None:
        raise ValueError(f"Could not find ZIP/ZCTA column in {path}")

    # population column
    pop_col = None
    if "B01003_001E" in cols:
        pop_col = "B01003_001E"
    else:
        for c in df.columns:
            if re.search(r"B01003[_A-Z0-9]*001E", c):
                pop_col = c
                break
        if pop_col is None:
            label_like = [c for c in df.columns if "Estimate" in c and ("Total" in c or "total" in c)]
            for c in label_like:
                try:
                    pd.to_numeric(df[c].str.replace(",",""), errors="raise")
                    pop_col = c
                    break
                except Exception:
                    pass
    if pop_col is None:
        raise ValueError(f"Could not find population column (B01003_001E) in {path}")

    out = pd.DataFrame({
        "zip": df[zip_col].astype(str).str.extract(r"(\d{5})", expand=False).str.zfill(5),
        "population": pd.to_numeric(df[pop_col].astype(str).str.replace(",",""), errors="coerce")
    }).dropna(subset=["zip"])
    out = out.groupby("zip", as_index=False)["population"].max()
    return out

acs_files = sorted(glob.glob(os.path.join(ACS_DIR, "*.csv")))
if not acs_files:
    print(f"No ACS CSVs found in {ACS_DIR}. (Skip if you haven't placed the files yet.)")
else:
    acs_parts = []
    for f in acs_files:
        try:
            part = normalize_acs_file(f)
            acs_parts.append(part)
            print(f" - Ingested {os.path.basename(f)} ({len(part):,} rows)")
        except Exception as e:
            print(f"Skipping {os.path.basename(f)}: {e}")
    if acs_parts:
        acs_all = pd.concat(acs_parts, ignore_index=True).groupby("zip", as_index=False)["population"].max()
        zip_universe = zip_universe.drop(columns=["population"], errors="ignore").merge(acs_all, on="zip", how="left")
        cover = 100*zip_universe["population"].notna().mean()
        print(f"Merged population. Coverage: {cover:.1f}% of ZIPs")
    else:
        print("No usable ACS files parsed.")

# %%
# 7) Build BallTrees and compute 50-mile coverage flags
print("Step 7: Build BallTrees + coverage flags (50 miles)")
import numpy as np
from sklearn.neighbors import BallTree

EARTH_RADIUS_MILES = 3958.7613
RADIUS_MILES = 50.0
radius_radians = RADIUS_MILES / EARTH_RADIUS_MILES

def build_tree(df):
    pts = np.deg2rad(df[["lat","lon"]].values)
    return BallTree(pts, metric="haversine"), pts

if len(trial_sites) == 0:
    raise ValueError("No geocoded trial sites available. Check Step 4 and Step 5.")

any_tree, any_pts = build_tree(trial_sites)

trees_by_cancer = {}
for cancer, dfc in trial_sites.groupby("cancer_type"):
    trees_by_cancer[cancer] = build_tree(dfc)

query_pts = np.deg2rad(zip_universe[["lat","lon"]].values)

ind_any = any_tree.query_radius(query_pts, r=radius_radians)
zip_universe["covered_any_gi_50mi"] = [1 if len(ix)>0 else 0 for ix in ind_any]

for cancer, (tree, _) in trees_by_cancer.items():
    inds = tree.query_radius(query_pts, r=radius_radians)
    flag = [1 if len(ix)>0 else 0 for ix in inds]
    col = f"covered_{cancer}_50mi"
    import re as _re
    col = _re.sub(r"[^a-z0-9_]+","_", col.lower())
    zip_universe[col] = flag

print("Coverage columns added.")

# %%
# 8) Summaries (unweighted + population-weighted if available)
print("Step 8: Summaries")
import pandas as pd
import numpy as np

def summarize_coverage(df, cover_col, weight_col=None):
    dfx = df[df["rural_urban"].isin(["Urban","Rural"])].copy()
    if not len(dfx):
        return pd.DataFrame()
    if weight_col and weight_col in dfx.columns and dfx[weight_col].notna().any():
        grp = dfx.groupby("rural_urban").apply(
            lambda g: pd.Series({
                "n_zips": len(g),
                "share_covered_unweighted": g[cover_col].mean(),
                "pop_covered": (g[cover_col] * g[weight_col]).sum(skipna=True),
                "pop_total": g[weight_col].sum(skipna=True)
            })
        ).reset_index()
        grp["share_covered_weighted"] = grp["pop_covered"] / grp["pop_total"]
        grp["coverage_flag"] = cover_col
        grp = grp.drop(columns=["pop_covered","pop_total"])
    else:
        grp = dfx.groupby("rural_urban").agg(
            n_zips=("zip","count"),
            share_covered_unweighted=(cover_col,"mean")
        ).reset_index()
        grp["coverage_flag"] = cover_col
    return grp

summary_any = summarize_coverage(zip_universe, "covered_any_gi_50mi", weight_col="population")
cancer_cols = [c for c in zip_universe.columns if c.startswith("covered_") and c.endswith("_50mi") and c != "covered_any_gi_50mi"]
summary_cancers = pd.concat([summarize_coverage(zip_universe, c, weight_col="population") for c in cancer_cols], ignore_index=True) if cancer_cols else pd.DataFrame()

print("Any GI (50mi):")
display(summary_any)
print("\nFirst few cancer-specific rows:")
display(summary_cancers.head())

# %%
# 9) Export outputs
print("Step 9: Export CSVs to ../out")
import os
os.makedirs("../out", exist_ok=True)

zip_universe_out = "../out/zip_coverage_50mi_with_ruca.csv"
summary_any_out   = "../out/summary_any_gi_50mi.csv"
summary_cancer_out= "../out/summary_by_cancer_50mi.csv"

zip_universe.to_csv(zip_universe_out, index=False)
summary_any.to_csv(summary_any_out, index=False)
summary_cancers.to_csv(summary_cancer_out, index=False)

print("Wrote:")
print(" -", zip_universe_out)
print(" -", summary_any_out)
print(" -", summary_cancer_out)

# %%
# 10) QC + (optional) impute missing RUCA + effect sizes with 95% CIs
print("Step 10: QC and inference")
import numpy as np
import pandas as pd
from sklearn.neighbors import BallTree
from statsmodels.stats.proportion import proportions_ztest

# QC
print("ZIP universe rows:", len(zip_universe))
print(zip_universe["rural_urban"].value_counts(dropna=False))
missing_ruca = zip_universe["rural_urban"].isna().sum()
if missing_ruca:
    print(f"WARNING: {missing_ruca} ZIPs missing RUCA. Imputing via nearest neighbor...")
    mis = zip_universe[zip_universe["rural_urban"].isna()][["zip","lat","lon"]].copy()
    known = zip_universe[zip_universe["rural_urban"].notna()][["zip","lat","lon","rural_urban"]].copy()
    known_pts = np.deg2rad(known[["lat","lon"]].to_numpy())
    tree_known = BallTree(known_pts, metric="haversine")
    q_pts = np.deg2rad(mis[["lat","lon"]].to_numpy())
    _, ind = tree_known.query(q_pts, k=1)
    imputed_ru = known.iloc[ind.ravel()]["rural_urban"].to_numpy()
    mis["rural_urban_imputed"] = imputed_ru
    zip_universe = zip_universe.merge(mis[["zip","rural_urban_imputed"]], on="zip", how="left")
    zip_universe["rural_urban"] = zip_universe["rural_urban"].fillna(zip_universe["rural_urban_imputed"])
    zip_universe = zip_universe.drop(columns=["rural_urban_imputed"])
    print("Remaining missing RUCA after impute:", zip_universe["rural_urban"].isna().sum())

# Effects with CIs
def rd_ci_normal(p1, n1, p2, n2):
    se = np.sqrt(p1*(1-p1)/n1 + p2*(1-p2)/n2)
    z = 1.959963984540054
    return ((p2 - p1) - z*se, (p2 - p1) + z*se)

def rr_and_ci(count1, n1, count2, n2):
    # RR = p2/p1; use Katz log CI
    # handle extremes with 0.5 correction
    if count1 == 0 or count2 == 0 or count1 == n1 or count2 == n2:
        count1 += 0.5; count2 += 0.5; n1 += 1.0; n2 += 1.0
    p1 = count1 / n1; p2 = count2 / n2
    rr = p2 / p1
    se_log = np.sqrt((1 - p1)/count1 + (1 - p2)/count2)
    z = 1.959963984540054
    lo = np.exp(np.log(rr) - z*se_log)
    hi = np.exp(np.log(rr) + z*se_log)
    return rr, (lo, hi)

def summarize_effects_with_ci(df, coverage_cols):
    rows = []
    for col in coverage_cols:
        dfx = df[df["rural_urban"].isin(["Urban","Rural"])][["rural_urban", col]].copy()
        tab = dfx.groupby("rural_urban")[col].agg(["sum","count"]).rename(columns={"sum":"x","count":"n"})
        if not set(["Urban","Rural"]).issubset(tab.index): 
            continue
        x_r, n_r = int(tab.loc["Rural","x"]),  int(tab.loc["Rural","n"])
        x_u, n_u = int(tab.loc["Urban","x"]),  int(tab.loc["Urban","n"])
        p_r, p_u = x_r/n_r, x_u/n_u
        z, pval = proportions_ztest([x_r, x_u], [n_r, n_u], alternative="two-sided")
        rd_lo, rd_hi = rd_ci_normal(p_r, n_r, p_u, n_u)
        rr, (rr_lo, rr_hi) = rr_and_ci(x_r, n_r, x_u, n_u)
        rows.append({
            "coverage_flag": col,
            "n_rural": n_r, "x_rural": x_r, "p_rural": p_r,
            "n_urban": n_u, "x_urban": x_u, "p_urban": p_u,
            "risk_difference": p_u - p_r, "rd_95ci_low": rd_lo, "rd_95ci_high": rd_hi,
            "risk_ratio": rr, "rr_95ci_low": rr_lo, "rr_95ci_high": rr_hi,
            "z_stat": z, "p_value": pval
        })
    return pd.DataFrame(rows)

coverage_cols = ["covered_any_gi_50mi"] + [c for c in zip_universe.columns if c.startswith("covered_") and c.endswith("_50mi") and c != "covered_any_gi_50mi"]
effects_ci = summarize_effects_with_ci(zip_universe, coverage_cols).sort_values("risk_difference", ascending=False).reset_index(drop=True)
display(effects_ci)

import os
os.makedirs("../out", exist_ok=True)
effects_ci.to_csv("../out/effects_50mi_by_cancer_with_ci_raw.csv", index=False)
print("Saved ../out/effects_50mi_by_cancer_with_ci_raw.csv")

# %%
# 11) Multi-radius sensitivity (Any GI + per cancer)
print("Step 11: Multi-radius coverage")
import numpy as np

RADII = [30, 50, 60, 120]

def coverage_flags_for_radius(tree, query_pts, radius_miles):
    EARTH_RADIUS_MILES = 3958.7613
    r_rad = radius_miles / EARTH_RADIUS_MILES
    inds = tree.query_radius(query_pts, r=r_rad)
    return np.array([1 if len(ix) > 0 else 0 for ix in inds], dtype=int)

query_pts = np.deg2rad(zip_universe[["lat","lon"]].values)

for r in RADII:
    zip_universe[f"covered_any_gi_{r}mi"] = coverage_flags_for_radius(any_tree, query_pts, r)

for cancer, (tree, _) in trees_by_cancer.items():
    for r in RADII:
        col = f"covered_{cancer}_{r}mi"
        import re as _re
        col = _re.sub(r"[^a-z0-9_]+", "_", col.lower())
        zip_universe[col] = coverage_flags_for_radius(tree, query_pts, r)

# summarize any-GI by radius
def summarize_radius(df, radii):
    out = []
    for r in radii:
        col = f"covered_any_gi_{r}mi"
        s = summarize_coverage(df, col, weight_col="population")
        s["radius_mi"] = r
        out.append(s)
    return pd.concat(out, ignore_index=True)

sens_any = summarize_radius(zip_universe, RADII)
display(sens_any)
sens_any.to_csv("../out/summary_any_gi_multi_radius.csv", index=False)
print("Saved ../out/summary_any_gi_multi_radius.csv")

# %%
# 12) State-level summaries (Any GI, 50mi)
print("Step 12: State-level summaries")
import pandas as pd

ruca_full = pd.read_csv(RUCA_CSV, dtype=str)
ruca_full["zip"] = ruca_full["ZIPCode"].str.extract(r"(\d{5})").fillna("")
ruca_full["zip"] = ruca_full["zip"].str.zfill(5)

zip_universe = zip_universe.drop(columns=[c for c in ["State"] if c in zip_universe.columns])
zip_universe = zip_universe.merge(ruca_full[["zip","State"]], on="zip", how="left")

def summarize_by_state(df, cover_col):
    dfx = df[df["rural_urban"].isin(["Urban","Rural"])].dropna(subset=["State"]).copy()
    grp = dfx.groupby(["State","rural_urban"]).agg(
        n_zips=("zip","count"),
        share_covered_unweighted=(cover_col,"mean")
    ).reset_index()
    grp["coverage_flag"] = cover_col
    return grp

state_any_50 = summarize_by_state(zip_universe, "covered_any_gi_50mi")
state_any_50.to_csv("../out/state_any_gi_50mi.csv", index=False)
display(state_any_50.head())
print("Saved ../out/state_any_gi_50mi.csv")

# %%
# 13) Figures (optional)
print("Step 13: Figures (optional)")
# Any GI coverage vs radius
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

radii = [30, 50, 60, 120]
plot_rows = []
for r in radii:
    col = f"covered_any_gi_{r}mi"
    if col not in zip_universe.columns:
        continue
    tmp = zip_universe[zip_universe["rural_urban"].isin(["Urban","Rural"])].copy()
    g = tmp.groupby("rural_urban")[col].mean().rename("share").reset_index()
    g["radius_mi"] = r
    plot_rows.append(g)
if plot_rows:
    plot_df = pd.concat(plot_rows, ignore_index=True)
    plt.figure(figsize=(7,5))
    for grp, gdf in plot_df.groupby("rural_urban"):
        gdf = gdf.sort_values("radius_mi")
        plt.plot(gdf["radius_mi"], 100*gdf["share"], marker="o", label=grp)
    plt.xlabel("Radius (miles)")
    plt.ylabel("ZIPs covered (%)")
    plt.title("Any GI trial coverage vs distance by rural/urban")
    plt.legend()
    plt.tight_layout()
    plt.savefig("../out/fig_anyGI_coverage_vs_radius.png", dpi=300)
    plt.show()
    print("Saved ../out/fig_anyGI_coverage_vs_radius.png")

# Bar chart by cancer type (50mi)
cancer_cols = [c for c in zip_universe.columns if c.startswith("covered_") and c.endswith("_50mi") and c != "covered_any_gi_50mi"]
if cancer_cols:
    rows = []
    for col in cancer_cols:
        name = col.replace("covered_","").replace("_50mi","").replace("_"," ").title()
        dfx = zip_universe[zip_universe["rural_urban"].isin(["Urban","Rural"])]
        g = dfx.groupby("rural_urban")[col].mean().rename("share").reset_index()
        g["cancer_type"] = name
        rows.append(g)
    tidy = pd.concat(rows, ignore_index=True)
    plt.figure(figsize=(9,5))
    cats = sorted(tidy["cancer_type"].unique())
    x = np.arange(len(cats))
    width = 0.38
    rural = tidy[tidy["rural_urban"]=="Rural"].set_index("cancer_type").reindex(cats)["share"].values
    urban = tidy[tidy["rural_urban"]=="Urban"].set_index("cancer_type").reindex(cats)["share"].values
    plt.bar(x - width/2, 100*rural, width, label="Rural")
    plt.bar(x + width/2, 100*urban, width, label="Urban")
    plt.xticks(x, cats, rotation=30, ha="right")
    plt.ylabel("ZIPs covered (%)")
    plt.title("Coverage within 50 miles by cancer type")
    plt.legend()
    plt.tight_layout()
    plt.savefig("../out/fig_coverage_50mi_by_cancer.png", dpi=300)
    plt.show()
    print("Saved ../out/fig_coverage_50mi_by_cancer.png")
