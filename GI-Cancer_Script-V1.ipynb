# %%
import pandas as pd

# %%
df = pd.read_csv("data/gastric_cancer.csv")


display(df.head(3))
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
#     NCT Number                                        Study Title  \
# 0  NCT01416714  Tissue Procurement for Gastric Cancer, Gastroi...
# 1  NCT06408220  Risk Assessment Evaluation for Identifying Par...
# 2  NCT07070466  Ivonescimab in Comb. With FOLFOX in Advanced H...
#
#                                           Conditions  \
# 0                                    Gastric Cancers
# 1                                  Gastric Carcinoma
# 2  Stomach Cancer Stage IV|Esophagus Cancer|Stoma...
#
#                                        Interventions  \
# 0                                                NaN
# 1  PROCEDURE: Biopsy|PROCEDURE: Biospecimen Colle...
# 2  DRUG: Ivonescimab|DRUG: 5-Fluorouracil|DRUG: O...
#
#                           Sponsor  \
# 0           University of Chicago
# 1     City of Hope Medical Center
# ...
